# %% [markdown]
# # Projeto para Departamento de Marketing
#
# objetivo com esse projeto é criar um assistente de geração de conteúdo automatizado, que adapta o texto ao público e ao canal de divulgação.

# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 10.9 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.37.1

# %%
# !pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-1.1.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-groq) (1.1.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.4.56)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.12.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.5.0)
# Downloading langchain_groq-1.1.1-py3-none-any.whl (19 kB)
# Installing collected packages: langchain-groq
# Successfully installed langchain-groq-1.1.1

# %%
from google.colab import widgets
import ipywidgets as widgets

from langchain_groq import ChatGroq
import os
import getpass

# %%
from ipywidgets.widgets.widget_layout import Layout
topic = widgets.Text(
    description = 'Tema:',
    placeholder = 'Ex: saúde mental, alimentação saudável, prevenção, etc.',
    layout = widgets.Layout(width='500px')
)

# %%
display(topic)
# Out:
# Text(value='', description='Tema:', layout=Layout(width='500px'), placeholder='Ex: saúde mental, alimentação s…

# %%
display(topic.value)
# Out:
# ''

# %%
w_dropdown = '250px'

platform = widgets.Dropdown(
    options = ['Instagram', 'Facebook', 'LinkedIn', 'Blog', 'E-mail'],
    description = 'Plataforma',
    layout = widgets.Layout(width = w_dropdown)
)

tone = widgets.Dropdown(
    options=['Normal', 'Informativo', 'Inspirador', 'Urgente', 'Informal'],
    description='Tom:',
    layout=widgets.Layout(width=w_dropdown)
)

length = widgets.Dropdown(
    options=['Curto', 'Médio', 'Longo'],
    description='Tamanho:',
    layout=widgets.Layout(width=w_dropdown)
)

audience = widgets.Dropdown(
    options=['Geral', 'Jovens adultos', 'Famílias', 'Idosos', 'Adolescentes'],
    description='Público-alvo:',
    layout=widgets.Layout(width=w_dropdown)
)


display(platform, tone, length, audience)
# Out:
# Dropdown(description='Plataforma', layout=Layout(width='250px'), options=('Instagram', 'Facebook', 'LinkedIn',…
# Dropdown(description='Tom:', layout=Layout(width='250px'), options=('Normal', 'Informativo', 'Inspirador', 'Ur…
# Dropdown(description='Tamanho:', layout=Layout(width='250px'), options=('Curto', 'Médio', 'Longo'), value='Cur…
# Dropdown(description='Público-alvo:', layout=Layout(width='250px'), options=('Geral', 'Jovens adultos', 'Famíl…

# %%
cta = widgets.Checkbox(
    value = False,
    description = 'Incluir CTA'
)

hashtags = widgets.Checkbox(
    value=False,
    description='Retornar Hashtags',
)

# %%
display(cta)
# Out:
# Checkbox(value=False, description='Incluir CTA')

# %%
display(cta.value)
# Out:
# False

# %%
keywords = widgets.Textarea(
    description = 'Palavras-chave (SEO)',
    placeholder = 'Ex: bem-estar, medicina preventiva...',
    layout = widgets.Layout(width = '500px', height = '50px')
)

# %%
display(keywords)
# Out:
# Textarea(value='', description='Palavras-chave (SEO)', layout=Layout(height='50px', width='500px'), placeholde…

# %%
generate_button = widgets.Button(
    description = 'Gerar conteúdo',
)

display(generate_button)
# Out:
# Button(description='Gerar conteúdo', style=ButtonStyle())

# %%
output = widgets.Output()

# %%
def generate_resul(b):
  with output:
    output.clear_output()
    print("Ok")

# %%
generate_button.on_click(generate_resul)

# %%
display(generate_button, output)
# Out:
# Button(description='Gerar conteúdo', style=ButtonStyle())
# Output()

# %%
def create_form():
  return widgets.VBox([
      topic,
      platform,
      tone,
      length,
      audience,
      cta,
      hashtags,
      keywords,
      generate_button,
      output
  ])

form = create_form()

display(form)
# Out:
# VBox(children=(Text(value='', description='Tema:', layout=Layout(width='500px'), placeholder='Ex: saúde mental…

# %%
os.environ["GROQ_API_KEY"] = getpass.getpass()
# Out:
# ··········

# %%
id_model = "llama-3.3-70b-versatile" #@param {type: "string"}

llm = ChatGroq(
    model = id_model,
    temperature = 0.7,
    max_tokens=None,
    timeout = None,
    max_retries = 2,
)

# %%
prompt = "Oi quem é você?" #@param {type: "string"}
template = [
    ("system", "Você é um redator profissional."),
    ("human", prompt)
]

res = llm.invoke(template)
res
# Out:
# AIMessage(content='Olá! Eu sou um assistente de linguagem treinado por máquina, mas também sou um redator profissional. Isso significa que posso ajudar a criar conteúdo de alta qualidade, seja ele um artigo, um relatório, um texto de marketing ou qualquer outro tipo de escrita.\n\nEstou aqui para ajudar com qualquer coisa que você precise em termos de redação, seja para criar conteúdo do zero ou para revisar e editar textos existentes. Minhas habilidades incluem:\n\n* Criar conteúdo interessante e atraente\n* Revisar e editar textos para garantir clareza e precisão\n* Desenvolver estratégias de comunicação eficazes\n* Escrever em diferentes estilos e formatos\n\nSe você tiver alguma necessidade específica ou quiser discutir um projeto, estou aqui para ajudar! Qual é o seu objetivo ou necessidade em termos de redação?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 207, 'prompt_tokens': 48, 'total_tokens': 255, 'completion_time': 0.591471535, 'completion_tokens_details': None, 'prompt_time': 0.004476703, 'prompt_tokens_details': None, 'queue_time': 0.008567752, 'total_time': 0.595948238}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_43d97c5965', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b2373-ad19-7003-b8aa-32df0bcf33a3-0', usage_metadata={'input_tokens': 48, 'output_tokens': 207, 'total_tokens': 255})

# %%
res.content
# Out:
# 'Olá! Eu sou um assistente de linguagem treinado por máquina, mas também sou um redator profissional. Isso significa que posso ajudar a criar conteúdo de alta qualidade, seja ele um artigo, um relatório, um texto de marketing ou qualquer outro tipo de escrita.\n\nEstou aqui para ajudar com qualquer coisa que você precise em termos de redação, seja para criar conteúdo do zero ou para revisar e editar textos existentes. Minhas habilidades incluem:\n\n* Criar conteúdo interessante e atraente\n* Revisar e editar textos para garantir clareza e precisão\n* Desenvolver estratégias de comunicação eficazes\n* Escrever em diferentes estilos e formatos\n\nSe você tiver alguma necessidade específica ou quiser discutir um projeto, estou aqui para ajudar! Qual é o seu objetivo ou necessidade em termos de redação?'

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = "Olá! quem é você?"  # @param {type:"string"}

template = ChatPromptTemplate.from_messages([
    ("system", "Você é um redator profissional"),
    ("human", "{prompt}")
])

chain = template | llm

res = chain.invoke({"prompt": prompt})
res.content
# Out:
# 'Olá! Eu sou um assistente virtual treinado por inteligência artificial, mas posso atuar como um redator profissional para ajudá-lo a criar conteúdo de alta qualidade. Com habilidades em redação, edição e revisão, estou aqui para auxiliá-lo em projetos de escrita, seja para criar textos para sites, blogs, artigos, relatórios ou qualquer outro tipo de conteúdo.\n\nPosso ajudá-lo a:\n\n* Criar textos originais e atraentes\n* Revisar e editar textos existentes para melhorar a clareza e a coesão\n* Desenvolver estratégias de conteúdo para alcançar seus objetivos\n* Pesquisar e fornecer informações precisas e atualizadas sobre um determinado tema\n\nEstou aqui para ajudá-lo a comunicar suas ideias de forma eficaz e atraente. Qual é o seu projeto ou necessidade de redação? Estou ansioso para saber mais e ajudá-lo a alcançar seus objetivos!'

# %%
from langchain_core.output_parsers import StrOutputParser

prompt = "Olá! quem é você?"  # @param {type:"string"}

template = ChatPromptTemplate.from_messages([
    ("system", "Você é um redator profissional"),
    ("human", "{prompt}")
])

chain = template | llm | StrOutputParser()

res = chain.invoke({"prompt": prompt})
res
# Out:
# 'Olá! Eu sou um assistente virtual treinado por inteligência artificial. Meu objetivo é ajudar e fornecer informações úteis para quem me consulta. Posso ser usado para uma variedade de tarefas, desde responder a perguntas e fornecer definições até criar textos e resumos. Estou aqui para ajudar no que precisar!\n\nNo contexto da sua pergunta inicial, mencionou que sou um redator profissional. Embora eu seja capaz de criar textos e conteúdos, é importante esclarecer que meu papel é mais amplo e abrange uma gama de funções, incluindo:\n\n- **Resposta a perguntas:** Posso fornecer informações sobre uma ampla gama de tópicos, desde ciência e história até entretenimento e cultura.\n- **Criação de textos:** Posso gerar textos, artigos, resumos e até histórias curtas com base nas instruções ou temas fornecidos.\n- **Tradução:** Posso traduzir textos de um idioma para outro, facilitando a comunicação global.\n- **Sugestões e ideias:** Posso ajudar a gerar ideias para projetos, títulos, ou até mesmo sugestões de presentes.\n\nEstou aqui para ajudar com qualquer coisa que você precise. Como posso ajudar você hoje?'

# %%
def show_res(res):
  from IPython.display import Markdown
  display(Markdown(res))

show_res(res)
# Out:
# Olá! Eu sou um assistente virtual treinado por inteligência artificial. Meu objetivo é ajudar e fornecer informações úteis para quem me consulta. Posso ser usado para uma variedade de tarefas, desde responder a perguntas e fornecer definições até criar textos e resumos. Estou aqui para ajudar no que precisar!
#
# No contexto da sua pergunta inicial, mencionou que sou um redator profissional. Embora eu seja capaz de criar textos e conteúdos, é importante esclarecer que meu papel é mais amplo e abrange uma gama de funções, incluindo:
#
# - **Resposta a perguntas:** Posso fornecer informações sobre uma ampla gama de tópicos, desde ciência e história até entretenimento e cultura.
# - **Criação de textos:** Posso gerar textos, artigos, resumos e até histórias curtas com base nas instruções ou temas fornecidos.
# - **Tradução:** Posso traduzir textos de um idioma para outro, facilitando a comunicação global.
# - **Sugestões e ideias:** Posso ajudar a gerar ideias para projetos, títulos, ou até mesmo sugestões de presentes.
#
# Estou aqui para ajudar com qualquer coisa que você precise. Como posso ajudar você hoje?

# %%
def llm_generate(llm, prompt):
  template = ChatPromptTemplate.from_messages([
      ("system", "Você é um redator profissional."),
      ("human", "{prompt}"),
  ])

  chain = template | llm | StrOutputParser()

  res = chain.invoke({"prompt": prompt})
  show_res(res)

# %%
prompt = "escreva 3 dicas de saúde"  # @param {type:"string"}

llm_generate(llm, prompt)
# Out:
# **Dicas de Saúde para uma Vida Mais Saudável**
#
# Aqui estão três dicas importantes para manter sua saúde em dia:
#
# 1. **Hidratação Adequada**: Beber água suficiente é fundamental para o funcionamento correto do corpo. A hidratação ajuda a regular a temperatura corporal, a manter a pele saudável e a auxiliar na digestão. É recomendado beber pelo menos 2 litros de água por dia, mas isso pode variar dependendo do nível de atividade física e do clima.
#
# 2. **Alimentação Balanceada**: Uma dieta equilibrada é essencial para fornecer ao corpo os nutrientes necessários para funcionar corretamente. Isso inclui uma variedade de frutas, legumes, proteínas magras, grãos integrais e gorduras saudáveis. Evite alimentos processados e ricos em açúcar e gordura, pois podem levar a problemas de saúde como obesidade, diabetes e doenças cardíacas.
#
# 3. **Atividade Física Regular**: A prática regular de exercícios é crucial para manter a saúde física e mental. A atividade física ajuda a controlar o peso, a fortalecer os ossos, a melhorar a qualidade do sono e a reduzir o estresse e a ansiedade. Não é necessário se tornar um atleta para se beneficiar da atividade física; mesmo pequenas quantidades de exercício, como caminhar por 30 minutos por dia, podem fazer uma grande diferença na sua saúde geral.
#
# Lembre-se de que pequenas mudanças nos hábitos diários podem levar a melhorias significativas na saúde a longo prazo. Consulte um profissional de saúde para obter orientação personalizada e começar a trabalhar em direção a uma vida mais saudável.

# %% [markdown]
# #Construindo o prompt de aplicação/engenharia de prompt

# %%
prompt = "fale sobre chocolate em 1 parágrafo"

template = ChatPromptTemplate.from_messages([
    ("system", "Você é um historiador"),
    ("human", "{prompt}")
])

chain = template | llm | StrOutputParser()

res = chain.invoke({"prompt": prompt})
show_res(res)
# Out:
# O chocolate! Uma delícia que remonta a milhares de anos atrás, quando os povos mesoamericanos começaram a cultivar e processar as sementes do cacau. Os astecas e maias consideravam o chocolate um presente dos deuses, utilizando-o em rituais e cerimônias sagradas. Com a conquista espanhola, o chocolate foi introduzido na Europa, onde se tornou um luxo exclusivo das classes altas. No entanto, foi apenas no século XIX, com a invenção do processo de conchagem, que o chocolate se tornou mais acessível e começou a ser produzido em massa. Hoje em dia, o chocolate é uma das guloseimas mais populares do mundo, com uma variedade de sabores e texturas que agradam a todos os gostos. Desde o amargo e intenso chocolate negro até o doce e cremoso chocolate branco, o chocolate é um tesouro gastronômico que continua a encantar e a deleitar as pessoas em todo o planeta.

# %%
template = ChatPromptTemplate.from_messages([
    ("system", "Você é um especialista em marketing digital."),
    ("human", "{prompt}"),
])

chain = template | llm | StrOutputParser()

res = chain.invoke({"prompt": prompt})
show_res(res)
# Out:
# O chocolate! É um dos doces mais amados e consumidos em todo o mundo. Com sua textura suave e sabor rico, é capaz de evocar sentimentos de prazer e felicidade em quem o saboreia. Desde os tempos antigos, o chocolate tem sido um símbolo de luxo e sofisticação, sendo considerado um presente nobre e exclusivo. Hoje em dia, o chocolate é produzido em uma variedade de formas e sabores, desde os clássicos tabletes de chocolate ao leite e amargo, até os mais refinados e gourmet, como os chocolates artesanais e os trufas. Além disso, o chocolate também é conhecido por seus benefícios para a saúde, como a redução do estresse e a melhoria do humor, o que o torna um alimento ainda mais especial e atraente para os consumidores.

# %%
template = ChatPromptTemplate.from_messages([
    ("system", "Você é um especialista em marketing digital com foco em SEO e escrita persuasiva."),
    ("human", "{prompt}"),
])

chain = template | llm | StrOutputParser()

res = chain.invoke({"prompt": prompt})
show_res(res)
# Out:
# O chocolate! É um dos doces mais amados e desejados do mundo, capaz de despertar emoções e sensações únicas em quem o degusta. Com sua textura suave e sabor rico, o chocolate é um prazer para os sentidos, seja em forma de barras, trufas, bombons ou outros tipos de doces. Além de ser um alimento delicioso, o chocolate também tem propriedades benéficas para a saúde, como reduzir o estresse e melhorar o humor, devido à presença de substâncias como a feniletilamina e a teobromina. Seja como um presente, um tratamento especial ou apenas um momento de indulgência, o chocolate é uma forma de se conectar com os outros e consigo mesmo, criando memórias e sensações que duram para sempre.

# %%
assunto = 'chocolate'

one_shot = f"""
Exemplo:
Título: Você sabia que beber mais água pode melhorar sua concentração?
Texto: A desidratação leve já é suficiente para reduzir seu foco e energia no dia a dia. Mantenha uma garrafinha por perto e lembre-se de se hidratar ao longo do dia.
Hashtags: #hidratação #foconasaude

Agora gere um novo texto que fale sobre {assunto}
"""

#print(one_shot)

res = chain.invoke({"prompt": one_shot})
show_res(res)
# Out:
# Título: Você sabia que o chocolate pode ser um aliado para a saúde mental?
# Texto: O chocolate contém flavonoides, que podem ajudar a reduzir o estresse e melhorar o humor. Além disso, o chocolate também pode aumentar a produção de serotonina, um neurotransmissor que regula a felicidade e a calma. Então, não hesite em se permitir um pedaço de chocolate amargo por dia e aproveite os benefícios para a sua saúde mental!
# Hashtags: #chocolateamargo #saudemental #bemestar

# %%
few_shot = f"""
Exemplo 1:
Título: Você sabia que beber mais água pode melhorar sua concentração?
Texto: A desidratação leve já é suficiente para reduzir seu foco e energia no dia a dia. Mantenha uma garrafinha por perto e lembre-se de se hidratar ao longo do dia.
Hashtags: #hidratação #foconasaude

Exemplo 2:
Título: Comer carboidratos à noite engorda: Mito ou verdade?
Texto: Esse é um mito comum. O que realmente importa é o total calórico do dia e a qualidade dos alimentos. Com orientação certa, dá sim para comer bem à noite sem culpa!
Hashtags: #nutricaosemmitos #equilibrioalimentar

Agora gere um novo texto que fale sobre {assunto}
"""

res = chain.invoke({"prompt": few_shot})
show_res(res)
# Out:
# Título: O Chocolate é o Vilão da Dieta? Descubra a Verdade!
# Texto: Muitas pessoas acreditam que o chocolate é um inimigo da saúde, mas a verdade é que, em moderação, ele pode ser benéfico! O chocolate contém flavonoides, que ajudam a melhorar a saúde cardiovascular e até mesmo a reduzir o estresse. Então, não precisa abrir mão dele completamente, apenas aproveite com responsabilidade!
# Hashtags: #chocolatesaudavel #moderacaoéchave

# %% [markdown]
# #Prompt estruturado

# %%
form = create_form()
display(form)
# Out:
# VBox(children=(Text(value='', description='Tema:', layout=Layout(width='500px'), placeholder='Ex: saúde mental…

# %%
prompt = f"""
Crie um post para {platform.value} com a seguinte estrutura:
1. Comece com uma pergunta provocativa.
2. Apresente um benefício claro relacionado ao tema.
3. Finalize com uma chamada para ação (CTA) encorajando o leitor a buscar mais informações.

Tema: {topic.value}
Público-alvo: {audience.value}
Tom: {tone.value}
"""

print(prompt)
# Out:
# Crie um post para Instagram com a seguinte estrutura:
# 1. Comece com uma pergunta provocativa.
# 2. Apresente um benefício claro relacionado ao tema.
# 3. Finalize com uma chamada para ação (CTA) encorajando o leitor a buscar mais informações.
#
# Tema:
# Público-alvo: Geral
# Tom: Normal

# %%
res = chain.invoke({"prompt": prompt})
show_res(res)
# Out:
# Você já parou para pensar em como melhorar a visibilidade da sua marca online?
#
# Com uma estratégia de SEO eficaz, você pode aumentar significativamente o tráfego orgânico do seu site, tornando sua marca mais visível e atraente para um público mais amplo. Isso pode levar a mais oportunidades de negócios e, consequentemente, a um aumento nas vendas e na receita.
#
# Quer aprender mais sobre como otimizar seu site para os motores de busca e levar seu negócio ao próximo nível? Clique no link na nossa bio para descobrir dicas e estratégias práticas de SEO que podem ajudar a impulsionar seu sucesso online! #SEO #MarketingDigital #VisibilidadeOnline

# %% [markdown]
# #concluindo

# %%
def llm_generate(llm, prompt):
  template = ChatPromptTemplate.from_messages([
      ("system", "Você é um especialista em marketing digital com foco em SEO e escrita persuasiva."),
      ("human", "{prompt}"),
  ])

  chain = template | llm | StrOutputParser()

  res = chain.invoke({"prompt": prompt})
  return res

# %%
def generate_result(b):
  with output:
    output.clear_output()
    prompt = f"""
    Escreva um texto com SEO otimizado sobre o tema '{topic.value}'.
    Retorne em sua resposta apenas o texto final e não inclua ela dentro de aspas.
    - Onde será publicado: {platform.value}.
    - Tom: {tone.value}.
    - Público-alvo: {audience.value}.
    - Comprimento: {length.value}.
    - {"Inclua uma chamada para ação clara." if cta.value else "Não inclua chamada para ação"}
    - {"Retorne ao final do texto hashtags relevantes." if hashtags.value else "Não inclua hashtags."}
    {"- Palavras-chave que devem estar presentes nesse texto (para SEO): " + keywords.value if keywords.value else ""}
    """
    try:
      res = llm_generate(llm, prompt)
      show_res(res)
    except Exception as e:
      print(f"Erro: {e}")

# %%
output = widgets.Output()
generate_button = widgets.Button(description = "Gerar conteúdo")
generate_button.on_click(generate_result)
form = create_form()

# %%
display(form)
# Out:
# VBox(children=(Text(value='', description='Tema:', layout=Layout(width='500px'), placeholder='Ex: saúde mental…

# %%
opt_length = "Curto, Médio, Longo, 1 parágrafo, 1 página" # @param {type:"string"}
print(opt_length)
# Out:
# Curto, Médio, Longo, 1 parágrafo, 1 página

# %%
options_length = [x.strip() for x in opt_length.split(",")]

# %%
options_length
# Out:
# ['Curto', 'Médio', 'Longo', '1 parágrafo', '1 página']

# %%
length = widgets.Dropdown(
    options = options_length,
    description="Tamanho",
    layout=widgets.Layout(width=w_dropdown)
)

# %%
form = create_form()
output.clear_output()
display(form)
# Out:
# VBox(children=(Text(value='', description='Tema:', layout=Layout(width='500px'), placeholder='Ex: saúde mental…

# %%
# !pip install -q streamlit
# !npm install -q localtunnel
# !pip install -q python-dotenv
# Out:
# ⠙⠹⠸⠼⠴⠦
# up to date, audited 23 packages in 856ms
# ⠦
# ⠦3 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# 2 high severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# ⠦

# %%
# %%writefile .env
# GROQ_API_KEY=#####
# Out:
# Overwriting .env

# %%
# %%writefile app.py
import streamlit as st
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
load_dotenv()

## conexão com a LLM
id_model = "llama-3.3-70b-versatile"
llm = ChatGroq(
    model=id_model,
    temperature=0.7,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

## função de geração
def llm_generate(llm, prompt):
  template = ChatPromptTemplate.from_messages([
      ("system", "Você é um especialista em marketing digital com foco em SEO e escrita persuasiva."),
      ("human", "{prompt}"),
  ])

  chain = template | llm | StrOutputParser()

  res = chain.invoke({"prompt": prompt})
  return res

st.set_page_config(page_title = "Gerador de conteúdo 🤖", page_icon="🤖")
st.title("Gerador de conteúdo")

# Campos do formulário
topic = st.text_input("Tema:", placeholder="Ex: saúde mental, alimentação saudável, prevenção, etc.")
platform = st.selectbox("Plataforma:", ['Instagram', 'Facebook', 'LinkedIn', 'Blog', 'E-mail'])
tone = st.selectbox("Tom:", ['Normal', 'Informativo', 'Inspirador', 'Urgente', 'Informal'])
length = st.selectbox("Tamanho:", ['Curto', 'Médio', 'Longo'])
audience = st.selectbox("Público-alvo:", ['Geral', 'Jovens adultos', 'Famílias', 'Idosos', 'Adolescentes'])
cta = st.checkbox("Incluir CTA")
hashtags = st.checkbox("Retornar Hashtags")
keywords = st.text_area("Palavras-chave (SEO):", placeholder="Ex: bem-estar, medicina preventiva...")

if st.button("Gerar conteúdo"):
  prompt = f"""
  Escreva um texto com SEO otimizado sobre o tema '{topic}'.
  Retorne em sua resposta apenas o texto final e não inclua ela dentro de aspas.
  - Onde será publicado: {platform}.
  - Tom: {tone}.
  - Público-alvo: {audience}.
  - Comprimento: {length}.
  - {"Inclua uma chamada para ação clara." if cta else "Não inclua chamada para ação"}
  - {"Retorne ao final do texto hashtags relevantes." if hashtags else "Não inclua hashtags."}
  {"- Palavras-chave que devem estar presentes nesse texto (para SEO): " + keywords if keywords else ""}
  """
  try:
      res = llm_generate(llm, prompt)
      st.markdown(res)
  except Exception as e:
      st.error(f"Erro: {e}")
# Out:
# Overwriting app.py

# %%
# !pip install pyngrok
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.12/dist-packages (7.5.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)

# %%
from pyngrok import ngrok

# !ngrok config add-authtoken 
# !streamlit run app.py --server.port 8501 &>/content/logs.txt &

public_url = ngrok.connect(8501)
public_url
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# <NgrokTunnel: "https://stephanie-nondisciplinary-bonnie.ngrok-free.dev" -> "http://localhost:8501">
